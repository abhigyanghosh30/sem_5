# %%
import numpy as np
from matplotlib import pyplot as plt
import csv

data = []
y_column = []
with open('data.csv','r')as f:
    rawdata = csv.reader(f)
    for row in rawdata:
        data.append(row[:-1])
        y_column.append(row[-1])
y_column = np.matrix(y_column).astype(np.float)
data = np.matrix(data).astype(np.float)

# %%
means = np.mean(data,axis=0)
var = np.sqrt(np.var(data,axis=0))
data = (data-means)/var

# %%
def hessian(x):
    n = x.shape[0]
    d = x.shape[1]
    H = np.zeros((d,d))
    for i in range(d):
        for j in range(d):
            sum=0
            for k in range(n):
                sum += x[k,i] * x[k,j]
            H[i][j] = sum/d 
    return 2*H

# %%
H = hessian(data)
H_inv = np.linalg.inv(H)

# %%
print(np.dot(np.ones(5),data[1].T).shape)
print(y_column[0,1])
print(np.zeros(5).reshape((1,5)).shape)
# Out:
# (1, 1)
# 125.201
# (1, 5)

# %%
def devfunc(w):
    n = data.shape[0]
    d = data.shape[1]
    sum_mat = np.zeros(d)
    for i in range(n):
        store = y_column[0,i] - np.dot(w, data[i].T)
        store = (-1) * store * data[i]
        sum_mat = sum_mat + store
    return sum_mat * 2/n

# %%
def normal_grad(learn=0.01,theta=0.01):
    n = data.shape[0]
    d = data.shape[1]
    
    w_old = np.ones(d).reshape((1,5))
    w_new = np.zeros(d).reshape((1,5))
    
    iters=0
    while(np.linalg.norm(w_old-w_new)>theta):
        dev = devfunc(w_old)
        w_old = w_new
        w_new = w_new - learn * dev
        iters+=1
        print(w_new,iters)
    return iters

# %%
itcount1 = normal_grad()

# %%
def newton_grad(learn=0.01,theta=0.01):
    n = data.shape[0]
    d = data.shape[1]
    
    w_old = np.ones(d).reshape((1,5))
    w_new = np.zeros(d).reshape((1,5))
    
    iters=0
    while(np.linalg.norm(w_old-w_new)>theta):
        dev = devfunc(w_old)
        w_old = w_new
        w_new = w_new - np.dot(dev,H_inv)
        iters+=1
        print(w_new,iters)
    return iters

# %%
itcount2 = newton_grad()
# Out:
# (1, 5)
# [[-0.01676948 -0.0116304  -0.01442838  0.0018446  -0.00976844]] 1
# (1, 5)
# [[-0.03021229 -0.01993411 -0.02553008  0.00701589 -0.01621019]] 2
# (1, 5)
# [[-0.0435993  -0.02819913 -0.03658378  0.01218104 -0.02261945]] 3
# (1, 5)
# [[-0.0569416  -0.03643654 -0.04760055  0.01732898 -0.02900728]] 4
# (1, 5)
# [[-0.07023936 -0.04464644 -0.05858055  0.02245974 -0.03537379]] 5
# (1, 5)
# [[-0.08349274 -0.05282894 -0.06952389  0.02757338 -0.04171905]] 6
# (1, 5)
# [[-0.09670188 -0.06098413 -0.08043072  0.03266995 -0.04804313]] 7
# (1, 5)
# [[-0.10986693 -0.0691121  -0.09130113  0.03774951 -0.0543461 ]] 8
# (1, 5)
# [[-0.12298804 -0.07721294 -0.10213526  0.04281211 -0.06062803]] 9
# (1, 5)
# [[-0.13606535 -0.08528675 -0.11293323  0.04785781 -0.06688899]] 10
# (1, 5)
# [[-0.14909901 -0.0933336  -0.12369516  0.05288667 -0.07312906]] 11
# [[-0.88826953 -0.54969008 -0.73403018  0.33808564 -0.42701831]] 74
# (1, 5)
# [[-0.89879247 -0.55618684 -0.742719    0.34214577 -0.43205633]] 75
# (1, 5)
# [[-0.90928029 -0.56266191 -0.75137881  0.34619235 -0.43707753]] 76
# (1, 5)
# [[-0.91973309 -0.56911537 -0.76000973  0.35022543 -0.44208197]] 77
# (1, 5)
# [[-0.93015101 -0.57554729 -0.76861183  0.35424504 -0.44706971]] 78
# (1, 5)
# [[-0.94053416 -0.58195774 -0.77718522  0.35825124 -0.4520408 ]] 79
# (1, 5)
# [[-0.95088265 -0.58834679 -0.78572999  0.36224406 -0.4569953 ]] 80
# (1, 5)
# [[-0.96119659 -0.59471452 -0.79424625  0.36622356 -0.46193326]] 81
# (1, 5)
# [[-0.97147612 -0.60106099 -0.80273407  0.37018977 -0.46685474]] 82
# (1, 5)
# [[-0.98172133 -0.60738628 -0.81119357  0.37414275 -0.47175979]] 83
# (1, 5)
# [[-0.99193234 -0.61369046 -0.81962483  0.37808253 -0.47664847]] 84
# (1, 5)
# [[-1.00210927 -0.6199736  -0.82802795  0.38200916 -0.48152083]] 85
# (1, 5)
# [[-1.01225223 -0.62623576 -0.83640302  0.38592269 -0.48637693]] 86
# (1, 5)
# [[-1.02236134 -0.63247702 -0.84475013  0.38982315 -0.49121682]] 87
# (1, 5)
# [[-1.0324367  -0.63869745 -0.85306939  0.39371059 -0.49604056]] 88
# (1, 5)
# [[-1.04247844 -0.64489712 -0.86136087  0.39758506 -0.50084819]] 89
# (1, 5)
# [[-1.05248665 -0.65107609 -0.86962469  0.4014466  -0.50563978]] 90
# (1, 5)
# [[-1.06246147 -0.65723444 -0.87786091  0.40529524 -0.51041537]] 91
# (1, 5)
# [[-1.07240298 -0.66337223 -0.88606965  0.40913104 -0.51517503]] 92
# (1, 5)
# [[-1.08231132 -0.66948954 -0.89425099  0.41295404 -0.5199188 ]] 93
# (1, 5)
# [[-1.09218658 -0.67558643 -0.90240502  0.41676428 -0.52464673]] 94
# (1, 5)
# [[-1.10202888 -0.68166296 -0.91053183  0.42056179 -0.52935888]] 95
# (1, 5)
# [[-1.11183833 -0.68771922 -0.91863152  0.42434664 -0.53405531]] 96
# (1, 5)
# [[-1.12161503 -0.69375526 -0.92670417  0.42811885 -0.53873605]] 97
# (1, 5)
# [[-1.13135911 -0.69977115 -0.93474987  0.43187847 -0.54340118]] 98
# (1, 5)
# [[-1.14107066 -0.70576697 -0.94276873  0.43562554 -0.54805073]] 99
# (1, 5)
# [[-1.15074979 -0.71174277 -0.95076081  0.4393601  -0.55268477]] 100
# (1, 5)
# [[-1.16039662 -0.71769862 -0.95872622  0.4430822  -0.55730333]] 101
# (1, 5)
# [[-1.17001124 -0.7236346  -0.96666504  0.44679187 -0.56190648]] 102
# (1, 5)
# [[-1.17959378 -0.72955076 -0.97457737  0.45048916 -0.56649427]] 103
# (1, 5)
# [[-1.18914433 -0.73544717 -0.98246328  0.45417411 -0.57106674]] 104
# (1, 5)
# [[-1.198663   -0.74132391 -0.99032288  0.45784677 -0.57562395]] 105
# (1, 5)
# [[-1.2081499  -0.74718102 -0.99815623  0.46150716 -0.58016595]] 106
# (1, 5)
# [[-1.21760514 -0.75301859 -1.00596345  0.46515533 -0.58469279]] 107
# (1, 5)
# [[-1.22702881 -0.75883667 -1.0137446   0.46879133 -0.58920452]] 108
# (1, 5)
# [[-1.23642104 -0.76463534 -1.02149978  0.47241519 -0.59370119]] 109
# (1, 5)
# [[-1.24578191 -0.77041464 -1.02922908  0.47602696 -0.59818285]] 110
# (1, 5)
# [[-1.25511153 -0.77617466 -1.03693257  0.47962667 -0.60264955]] 111
# (1, 5)
# [[-1.26441002 -0.78191545 -1.04461036  0.48321436 -0.60710135]] 112
# (1, 5)
# [[-1.27367747 -0.78763709 -1.05226251  0.48679008 -0.61153828]] 113
# (1, 5)
# [[-1.28291398 -0.79333962 -1.05988913  0.49035387 -0.61596041]] 114
# (1, 5)
# [[-1.29211967 -0.79902312 -1.06749029  0.49390576 -0.62036777]] 115
# (1, 5)
# [[-1.30129463 -0.80468764 -1.07506608  0.49744579 -0.62476042]] 116
# (1, 5)
# [[-1.31043896 -0.81033327 -1.08261658  0.50097401 -0.62913841]] 117
# (1, 5)
# [[-1.31955278 -0.81596004 -1.09014188  0.50449045 -0.63350179]] 118
# (1, 5)
# [[-1.32863617 -0.82156804 -1.09764206  0.50799516 -0.6378506 ]] 119
# (1, 5)
# [[-1.33768924 -0.82715731 -1.1051172   0.51148816 -0.6421849 ]] 120
# (1, 5)
# [[-1.3467121  -0.83272794 -1.1125674   0.51496951 -0.64650473]] 121
# (1, 5)
# [[-1.35570484 -0.83827996 -1.11999273  0.51843924 -0.65081015]] 122
# (1, 5)
# [[-1.36466756 -0.84381346 -1.12739327  0.52189738 -0.65510119]] 123
# (1, 5)
# [[-1.37360037 -0.84932848 -1.13476911  0.52534399 -0.65937791]] 124
# (1, 5)
# [[-1.38250336 -0.8548251  -1.14212034  0.52877909 -0.66364035]] 125
# (1, 5)
# [[-1.39137664 -0.86030337 -1.14944702  0.53220272 -0.66788857]] 126
# (1, 5)
# [[-1.40022029 -0.86576336 -1.15674925  0.53561492 -0.6721226 ]] 127
# (1, 5)
# [[-1.40903443 -0.87120512 -1.16402711  0.53901574 -0.67634251]] 128
# (1, 5)
# [[-1.41781915 -0.87662872 -1.17128068  0.54240521 -0.68054833]] 129
# (1, 5)
# [[-1.42657455 -0.88203421 -1.17851003  0.54578336 -0.68474011]] 130
# (1, 5)
# [[-1.43530072 -0.88742166 -1.18571525  0.54915023 -0.6889179 ]] 131
# (1, 5)
# [[-1.44399777 -0.89279113 -1.19289643  0.55250587 -0.69308174]] 132
# (1, 5)
# [[-1.45266578 -0.89814268 -1.20005363  0.55585031 -0.69723169]] 133
# (1, 5)
# [[-1.46130487 -0.90347637 -1.20718695  0.55918358 -0.70136778]] 134
# (1, 5)
# [[-1.46991512 -0.90879225 -1.21429645  0.56250573 -0.70549007]] 135
# (1, 5)
# [[-1.73077918 -1.06984711 -1.42969259  0.66315661 -0.83038275]] 167
# (1, 5)
# [[-1.73848998 -1.07460768 -1.43605941  0.66613171 -0.83407441]] 168
# (1, 5)
# [[-1.74617503 -1.07935235 -1.44240498  0.66909689 -0.83775375]] 169
# (1, 5)
# [[-1.75383443 -1.08408119 -1.44872937  0.67205216 -0.84142081]] 170
# (1, 5)
# [[-1.76146827 -1.08879425 -1.45503265  0.67499758 -0.84507563]] 171
# (1, 5)
# [[-1.76907663 -1.09349157 -1.46131489  0.67793316 -0.84871825]] 172
# (1, 5)
# [[-1.77665959 -1.09817322 -1.46757616  0.68085894 -0.85234871]] 173
# (1, 5)
# [[-1.78421724 -1.10283923 -1.47381653  0.68377496 -0.85596705]] 174
# (1, 5)
# [[-1.79174967 -1.10748968 -1.48003608  0.68668125 -0.85957331]] 175
# (1, 5)
# [[-1.79925695 -1.1121246  -1.48623486  0.68957783 -0.86316754]] 176
# (1, 5)
# [[-1.80673918 -1.11674405 -1.49241295  0.69246475 -0.86674977]] 177
# (1, 5)
# [[-1.81419643 -1.12134808 -1.49857042  0.69534203 -0.87032004]] 178
# (1, 5)
# [[-1.82162879 -1.12593675 -1.50470734  0.6982097  -0.8738784 ]] 179
# (1, 5)
# [[-1.82903634 -1.1305101  -1.51082378  0.70106781 -0.87742488]] 180
# (1, 5)
# [[-1.83641917 -1.13506818 -1.5169198   0.70391637 -0.88095952]] 181
# (1, 5)
# [[-1.84377736 -1.13961105 -1.52299547  0.70675543 -0.88448237]] 182
# (1, 5)
# [[-1.85111098 -1.14413876 -1.52905086  0.70958501 -0.88799345]] 183
# (1, 5)
# [[-1.85842013 -1.14865135 -1.53508605  0.71240514 -0.89149282]] 184
# (1, 5)
# [[-1.86570488 -1.15314888 -1.54110108  0.71521586 -0.8949805 ]] 185
# (1, 5)
# [[-1.87296531 -1.1576314  -1.54709604  0.7180172  -0.89845655]] 186
# (1, 5)
# [[-1.88020151 -1.16209896 -1.55307099  0.72080919 -0.90192099]] 187
# (1, 5)
# [[-1.88741356 -1.16655161 -1.559026    0.72359187 -0.90537387]] 188
# (1, 5)
# [[-1.89460153 -1.17098939 -1.56496113  0.72636525 -0.90881522]] 189
# (1, 5)
# [[-1.90176552 -1.17541236 -1.57087645  0.72912937 -0.91224509]] 190
# (1, 5)
# [[-1.90890559 -1.17982057 -1.57677202  0.73188427 -0.91566351]] 191
# (1, 5)
# [[-1.91602182 -1.18421406 -1.58264792  0.73462998 -0.91907052]] 192
# (1, 5)
# [[-1.92311431 -1.18859289 -1.5885042   0.73736652 -0.92246615]] 193
# (1, 5)
# [[-1.93018312 -1.19295711 -1.59434094  0.74009392 -0.92585046]] 194
# (1, 5)
# [[-1.93722834 -1.19730675 -1.60015819  0.74281223 -0.92922346]] 195
# (1, 5)
# [[-1.94425004 -1.20164188 -1.60595603  0.74552146 -0.93258521]] 196
# (1, 5)
# [[-1.95124831 -1.20596254 -1.61173451  0.74822164 -0.93593574]] 197
# (1, 5)
# [[-1.95822321 -1.21026878 -1.61749371  0.75091281 -0.93927508]] 198
# (1, 5)
# [[-1.96517484 -1.21456064 -1.62323369  0.75359501 -0.94260328]] 199
# (1, 5)
# [[-1.97210326 -1.21883818 -1.6289545   0.75626824 -0.94592037]] 200
# (1, 5)
# [[-1.97900855 -1.22310144 -1.63465622  0.75893256 -0.94922638]] 201
# (1, 5)
# [[-1.9858908  -1.22735047 -1.64033891  0.76158798 -0.95252136]] 202
# (1, 5)
# [[-1.99275008 -1.23158532 -1.64600263  0.76423454 -0.95580535]] 203
# (1, 5)
# [[-1.99958646 -1.23580603 -1.65164745  0.76687226 -0.95907837]] 204
# (1, 5)
# [[-2.00640002 -1.24001266 -1.65727343  0.76950118 -0.96234047]] 205
# (1, 5)
# [[-2.01319084 -1.24420524 -1.66288062  0.77212133 -0.96559168]] 206
# (1, 5)
# [[-2.01995899 -1.24838383 -1.66846911  0.77473273 -0.96883203]] 207
# (1, 5)
# [[-2.02670455 -1.25254847 -1.67403893  0.77733542 -0.97206157]] 208
# (1, 5)
# [[-2.0334276  -1.25669921 -1.67959017  0.77992941 -0.97528034]] 209
# (1, 5)
# [[-2.04012821 -1.2608361  -1.68512288  0.78251475 -0.97848835]] 210
# (1, 5)
# [[-2.04680645 -1.26495918 -1.69063712  0.78509146 -0.98168566]] 211
# (1, 5)
# [[-2.0534624  -1.2690685  -1.69613295  0.78765957 -0.9848723 ]] 212
# (1, 5)
# [[-2.06009613 -1.2731641  -1.70161044  0.7902191  -0.98804831]] 213
# (1, 5)
# [[-2.06670772 -1.27724603 -1.70706965  0.7927701  -0.99121371]] 214
# (1, 5)
# [[-2.07329724 -1.28131433 -1.71251064  0.79531258 -0.99436854]] 215
# (1, 5)
# [[-2.07986477 -1.28536906 -1.71793346  0.79784657 -0.99751285]] 216
# (1, 5)
# [[-2.08641038 -1.28941025 -1.72333819  0.8003721  -1.00064666]] 217
# (1, 5)
# [[-2.09293414 -1.29343796 -1.72872487  0.80288921 -1.00377001]] 218
# (1, 5)
# [[-2.09943612 -1.29745222 -1.73409358  0.80539791 -1.00688293]] 219
# (1, 5)
# [[-2.1059164  -1.30145308 -1.73944436  0.80789824 -1.00998547]] 220
# (1, 5)
# [[-2.11237506 -1.30544058 -1.74477729  0.81039022 -1.01307764]] 221
# (1, 5)
# [[-2.11881215 -1.30941478 -1.75009241  0.81287389 -1.0161595 ]] 222
# (1, 5)
# [[-2.12522776 -1.31337571 -1.7553898   0.81534926 -1.01923107]] 223
# (1, 5)
# [[-2.13162195 -1.31732342 -1.7606695   0.81781638 -1.02229239]] 224

# %%
def normal_grad(theta=0.01):
    n = data.shape[0]
    d = data.shape[1]
    
    w_old = np.ones(d).reshape((1,5))
    w_new = np.zeros(d).reshape((1,5))
    
    iters=0
    while(np.linalg.norm(w_old-w_new)>theta):
        dev = devfunc(w_old)
        w_old = w_new
        learn = np.power(np.linalg.norm(dev), 2) / (np.dot(dev, np.dot(Hessian, dev)))
        w_new = w_new - learn * dev
        iters+=1
        print(w_new,iters)
    return iters
